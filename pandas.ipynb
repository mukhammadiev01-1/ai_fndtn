# %% [markdown]
# <a href="https://colab.research.google.com/github/mukhammadiev01-1/ai_fndtn/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford", "Tesla", "KIA", "Honda", "Ford", "Toyota"],
  'passings': [3, 7, 2, 6, 8, 3, 5, 9]
}

df = pd.DataFrame(mydataset)
print(df)
# Out:
#      cars  passings
# 0     BMW         3
# 1   Volvo         7
# 2    Ford         2
# 3   Tesla         6
# 4     KIA         8
# 5   Honda         3
# 6    Ford         5
# 7  Toyota         9

# %%
df.head() #default 5 rows
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
# 3  Tesla         6
# 4    KIA         8

# %%
df.tail() #default 5 rows from last
# Out:
#      cars  passings
# 3   Tesla         6
# 4     KIA         8
# 5   Honda         3
# 6    Ford         5
# 7  Toyota         9

# %%
df.shape
# Out:
# (8, 2)

# %%
df.columns
# Out:
# Index(['cars', 'passings'], dtype='object')

# %%
df.dtypes
# Out:
# cars        object
# passings     int64
# dtype: object

# %%
df.describe(include="all") #numerical columns only
# Out:
#         cars  passings
# count      8  8.000000
# unique     7       NaN
# top     Ford       NaN
# freq       2       NaN
# mean     NaN  5.375000
# std      NaN  2.559994
# min      NaN  2.000000
# 25%      NaN  3.000000
# 50%      NaN  5.500000
# 75%      NaN  7.250000
# max      NaN  9.000000

# %%
df.iloc[0:3]
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
df.loc[2:6, "cars"]
# Out:
# 2     Ford
# 3    Tesla
# 4      KIA
# 5    Honda
# 6     Ford
# Name: cars, dtype: object

# %%
print(df)
# Out:
#      cars  passings
# 0     BMW         3
# 1   Volvo         7
# 2    Ford         2
# 3   Tesla         6
# 4     KIA         8
# 5   Honda         3
# 6    Ford         5
# 7  Toyota         9

# %%
df[df["passings"] > 3]
# Out:
#      cars  passings
# 1   Volvo         7
# 3   Tesla         6
# 4     KIA         8
# 6    Ford         5
# 7  Toyota         9

# %%
#df.mean(numeric_only=True)
df["passings"].mean()
# Out:
# np.float64(5.375)

# %%
df.sum()
# Out:
# cars        BMWVolvoFordTeslaKIAHondaFordToyota
# passings                                     43
# dtype: object

# %%
df.min()
# Out:
# cars        BMW
# passings      2
# dtype: object

# %%
df.max()
# Out:
# cars        Volvo
# passings        9
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# passings    5.5
# dtype: float64

# %%
df.count()
# Out:
# cars        8
# passings    8
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# passings    2.559994
# dtype: float64

# %%
data_with_missing = {
    "cars": ["BMW", "Volvo", None, "Tesla", "Ferrari", None, "Ford"],
    "counts": [3, 7, None, 8, 1, 9, None]
}

df_missing = pd.DataFrame(data_with_missing)
print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     None     NaN
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5     None     9.0
# 6     Ford     NaN

# %%
df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
df_missing.dropna(subset=["cars"])
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 6     Ford     NaN

# %%
df_missing.fillna(0)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2        0     0.0
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5        0     9.0
# 6     Ford     0.0

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head(100)

#
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head(100)

#df = pd.read_excel("Titanic-Dataset.xlsx")
#df = pd.read_json("Titanic-Dataset.json")
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df.to_excel("test.xlsx")

# %%
# Series => 1D
cars = pd.Series(["BMW", "Tesla", "Ferrari"])
print(cars)
# Out:
# 0        BMW
# 1      Tesla
# 2    Ferrari
# dtype: object

# %%
cars_series = data_with_missing["cars"]
print(cars_series)
# Out:
# ['BMW', 'Volvo', None, 'Tesla', 'Ferrari', None, 'Ford']
